# %%
import glob
import numpy as np
import os
import shutil
np.random.seed(42)

# %%
files = glob.glob('train/*')

cat_files = [fn for fn in files if 'cat' in fn]
dog_files = [fn for fn in files if 'dog' in fn]
len(cat_files), len(dog_files)
# Out:
# (901, 947)

# %%
cat_train = np.random.choice(cat_files, size=80, replace=False)
dog_train = np.random.choice(dog_files, size=80, replace=True)
cat_files = list(set(cat_files) - set(cat_train))
dog_files = list(set(dog_files) - set(dog_train))

cat_val = np.random.choice(cat_files, size=200, replace=False)
dog_val = np.random.choice(dog_files, size=200, replace=True)
cat_files = list(set(cat_files) - set(cat_val))
dog_files = list(set(dog_files) - set(dog_val))

cat_test = np.random.choice(cat_files, size=200, replace=False)
dog_test = np.random.choice(dog_files, size=200, replace=True)

print('Cat datasets:', cat_train.shape, cat_val.shape, cat_test.shape)
print('Dog datasets:', dog_train.shape, dog_val.shape, dog_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1ad2a0e67784> in <module>()
# ----> 1 cat_train = np.random.choice(cat_files, size=80, replace=False)
#       2 dog_train = np.random.choice(dog_files, size=80, replace=True)
#       3 cat_files = list(set(cat_files) - set(cat_train))
#       4 dog_files = list(set(dog_files) - set(dog_train))
#       5
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
train_dir = 'training_data'
val_dir = 'validation_data'
test_dir = 'test_data'

train_files = np.concatenate([cat_train, dog_train])
validate_files = np.concatenate([cat_val, dog_val])
test_files = np.concatenate([cat_test, dog_test])

os.mkdir(train_dir) if not os.path.isdir(train_dir) else None
os.mkdir(val_dir) if not os.path.isdir(val_dir) else None
os.mkdir(test_dir) if not os.path.isdir(test_dir) else None

for fn in train_files:
    shutil.copy(fn, train_dir)

for fn in validate_files:
    shutil.copy(fn, val_dir)
    
for fn in test_files:
    shutil.copy(fn, test_dir)

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
# %matplotlib inline


IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)

train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

print(train_imgs[1].shape)
array_to_img(train_imgs[1])

batch_size = 30
num_classes = 30
epochs =30


# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() 
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[2:11], train_labels_enc[2:11])


from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential
from keras import optimizers

model = Sequential()
input_shape = (150, 150, 3)


model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', 
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(),
              metrics=['accuracy'])

model.summary()



history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    validation_data=(validation_imgs_scaled, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# Train dataset shape: (152, 150, 150, 3) 	Validation dataset shape: (843, 150, 150, 3)
# (150, 150, 3)
# ['dog', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'cat'] [1 0 1 1 1 1 0 0 0]
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 72, 72, 64)        9280
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               18940416
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 19,024,513
# Trainable params: 19,024,513
# Non-trainable params: 0
# _________________________________________________________________
# Train on 152 samples, validate on 843 samples
# Epoch 1/30
# 152/152 [==============================] - 17s 110ms/step - loss: 6.8385 - acc: 0.5000 - val_loss: 5.0672 - val_acc: 0.5931
# Epoch 2/30
# 152/152 [==============================] - 16s 104ms/step - loss: 1.8589 - acc: 0.5329 - val_loss: 2.0558 - val_acc: 0.4069
# Epoch 3/30
# 152/152 [==============================] - 16s 104ms/step - loss: 0.9858 - acc: 0.5132 - val_loss: 1.3308 - val_acc: 0.4069
# Epoch 4/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.7692 - acc: 0.5132 - val_loss: 0.9131 - val_acc: 0.4069
# Epoch 5/30
# 152/152 [==============================] - 16s 104ms/step - loss: 0.6894 - acc: 0.6184 - val_loss: 0.6958 - val_acc: 0.6002
# Epoch 6/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.8048 - acc: 0.6645 - val_loss: 1.7081 - val_acc: 0.5931
# Epoch 7/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.9061 - acc: 0.6513 - val_loss: 0.7022 - val_acc: 0.5931
# Epoch 8/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.6597 - acc: 0.5658 - val_loss: 0.6763 - val_acc: 0.5457
# Epoch 9/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.7021 - acc: 0.6513 - val_loss: 0.8094 - val_acc: 0.5931
# Epoch 10/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.6051 - acc: 0.8158 - val_loss: 0.7065 - val_acc: 0.6157
# Epoch 11/30
# 152/152 [==============================] - 16s 102ms/step - loss: 0.7405 - acc: 0.6974 - val_loss: 0.7324 - val_acc: 0.4828
# Epoch 12/30
# 152/152 [==============================] - 15s 101ms/step - loss: 0.4686 - acc: 0.7829 - val_loss: 0.6805 - val_acc: 0.5623
# Epoch 13/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.4807 - acc: 0.8421 - val_loss: 0.9282 - val_acc: 0.5647
# Epoch 14/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.3444 - acc: 0.8487 - val_loss: 1.6850 - val_acc: 0.5991
# Epoch 15/30
# 152/152 [==============================] - 16s 104ms/step - loss: 0.3413 - acc: 0.8487 - val_loss: 1.6302 - val_acc: 0.6062
# Epoch 16/30
# 152/152 [==============================] - 16s 104ms/step - loss: 0.7966 - acc: 0.7895 - val_loss: 1.1561 - val_acc: 0.6133
# Epoch 17/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.2560 - acc: 0.9145 - val_loss: 0.9522 - val_acc: 0.6121
# Epoch 18/30
# 152/152 [==============================] - 16s 104ms/step - loss: 0.1601 - acc: 0.9671 - val_loss: 1.1798 - val_acc: 0.6002
# Epoch 19/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.1280 - acc: 0.9474 - val_loss: 2.2608 - val_acc: 0.6050
# Epoch 20/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.2931 - acc: 0.8618 - val_loss: 1.1889 - val_acc: 0.5694
# Epoch 21/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.0967 - acc: 0.9803 - val_loss: 3.0634 - val_acc: 0.4911
# Epoch 22/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.2483 - acc: 0.9145 - val_loss: 1.5484 - val_acc: 0.5682
# Epoch 23/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.0465 - acc: 0.9934 - val_loss: 1.9849 - val_acc: 0.5433
# Epoch 24/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.0434 - acc: 0.9934 - val_loss: 1.8701 - val_acc: 0.5836
# Epoch 25/30
# 152/152 [==============================] - 16s 104ms/step - loss: 0.0118 - acc: 1.0000 - val_loss: 2.0785 - val_acc: 0.5955
# Epoch 26/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 2.2238 - val_acc: 0.5979
# Epoch 27/30
# 152/152 [==============================] - 16s 102ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 2.3309 - val_acc: 0.5919
# Epoch 28/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.4491 - val_acc: 0.6026
# Epoch 29/30
# 152/152 [==============================] - 16s 103ms/step - loss: 7.4730e-04 - acc: 1.0000 - val_loss: 2.7170 - val_acc: 0.5848
# Epoch 30/30
# 152/152 [==============================] - 16s 103ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 4.8388 - val_acc: 0.5931

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['acc'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_acc'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential
from keras import optimizers

model = Sequential()
input_shape = (150, 150, 3)

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', 
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))


model.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(),
              metrics=['accuracy'])
              
              
history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    validation_data=(validation_imgs_scaled, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 152 samples, validate on 843 samples
# Epoch 1/30
# 152/152 [==============================] - 16s 105ms/step - loss: 1.1518 - acc: 0.4539 - val_loss: 0.6873 - val_acc: 0.5931
# Epoch 2/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.7034 - acc: 0.4803 - val_loss: 0.7481 - val_acc: 0.4069
# Epoch 3/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.6989 - acc: 0.5132 - val_loss: 0.6933 - val_acc: 0.4864
# Epoch 4/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.6920 - acc: 0.5197 - val_loss: 0.7338 - val_acc: 0.4069
# Epoch 5/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.7045 - acc: 0.5197 - val_loss: 0.6937 - val_acc: 0.4591
# Epoch 6/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.7139 - acc: 0.5329 - val_loss: 0.6995 - val_acc: 0.4247
# Epoch 7/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.6766 - acc: 0.5197 - val_loss: 0.6983 - val_acc: 0.4235
# Epoch 8/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.6540 - acc: 0.6250 - val_loss: 0.8046 - val_acc: 0.4330
# Epoch 9/30
# 152/152 [==============================] - 15s 99ms/step - loss: 0.7924 - acc: 0.5000 - val_loss: 0.6996 - val_acc: 0.4104
# Epoch 10/30
# 152/152 [==============================] - 15s 99ms/step - loss: 0.6918 - acc: 0.5395 - val_loss: 1.4780 - val_acc: 0.4069
# Epoch 11/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.8360 - acc: 0.4934 - val_loss: 0.7074 - val_acc: 0.4294
# Epoch 12/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.7020 - acc: 0.5461 - val_loss: 0.6951 - val_acc: 0.4401
# Epoch 13/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.6648 - acc: 0.5329 - val_loss: 0.7109 - val_acc: 0.4508
# Epoch 14/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.6893 - acc: 0.5724 - val_loss: 0.7004 - val_acc: 0.4662
# Epoch 15/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.6283 - acc: 0.6053 - val_loss: 0.7076 - val_acc: 0.4686
# Epoch 16/30
# 152/152 [==============================] - 15s 99ms/step - loss: 0.6366 - acc: 0.5395 - val_loss: 0.9631 - val_acc: 0.4152
# Epoch 17/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.8275 - acc: 0.5658 - val_loss: 0.9717 - val_acc: 0.4093
# Epoch 18/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.7322 - acc: 0.4803 - val_loss: 0.7168 - val_acc: 0.4294
# Epoch 19/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.6362 - acc: 0.6053 - val_loss: 2.3257 - val_acc: 0.5931
# Epoch 20/30
# 152/152 [==============================] - 15s 98ms/step - loss: 1.1254 - acc: 0.5592 - val_loss: 0.8325 - val_acc: 0.4674
# Epoch 21/30
# 152/152 [==============================] - 15s 99ms/step - loss: 1.1758 - acc: 0.6382 - val_loss: 2.0918 - val_acc: 0.5896
# Epoch 22/30
# 152/152 [==============================] - 15s 99ms/step - loss: 0.8690 - acc: 0.6184 - val_loss: 0.7347 - val_acc: 0.4852
# Epoch 23/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.5753 - acc: 0.6842 - val_loss: 1.5192 - val_acc: 0.4353
# Epoch 24/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.7217 - acc: 0.6250 - val_loss: 0.8797 - val_acc: 0.5172
# Epoch 25/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.5250 - acc: 0.7303 - val_loss: 0.8544 - val_acc: 0.5753
# Epoch 26/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.5188 - acc: 0.7368 - val_loss: 1.1053 - val_acc: 0.4638
# Epoch 27/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.5024 - acc: 0.7171 - val_loss: 2.1793 - val_acc: 0.4401
# Epoch 28/30
# 152/152 [==============================] - 15s 97ms/step - loss: 0.9469 - acc: 0.7039 - val_loss: 0.8214 - val_acc: 0.4508
# Epoch 29/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.5082 - acc: 0.6908 - val_loss: 0.9170 - val_acc: 0.4947
# Epoch 30/30
# 152/152 [==============================] - 15s 98ms/step - loss: 0.4193 - acc: 0.7829 - val_loss: 1.3265 - val_acc: 0.5326

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['acc'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_acc'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('cats_dogs_basic_cnn.h5')

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=50,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_id = 10
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
img_id = 101
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(15, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['dog', 'dog', 'dog', 'dog', 'dog']

# %%
train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=30)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=20
100
# 100/100 [==============================] - 121s 1s/step - loss: 0.1033 - acc: 0.9657 - val_loss: 2.9645 - val_acc: 0.6236
# Epoch 91/100
# 100/100 [==============================] - 119s 1s/step - loss: 0.0981 - acc: 0.9703 - val_loss: 2.1871 - val_acc: 0.6938
# Epoch 92/100
# 100/100 [==============================] - 119s 1s/step - loss: 0.0970 - acc: 0.9729 - val_loss: 1.8145 - val_acc: 0.7223
# Epoch 93/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.1153 - acc: 0.9677 - val_loss: 2.0464 - val_acc: 0.6770
# Epoch 94/100
# 100/100 [==============================] - 119s 1s/step - loss: 0.0774 - acc: 0.9796 - val_loss: 2.6641 - val_acc: 0.6877
# Epoch 95/100
# 100/100 [==============================] - 123s 1s/step - loss: 0.1306 - acc: 0.9647 - val_loss: 2.0471 - val_acc: 0.6684
# Epoch 96/100
# 100/100 [==============================] - 120s 1s/step - loss: 0.1058 - acc: 0.9679 - val_loss: 1.8102 - val_acc: 0.6958
# Epoch 97/100
# 100/100 [==============================] - 119s 1s/step - loss: 0.0897 - acc: 0.9673 - val_loss: 2.1045 - val_acc: 0.7060
# Epoch 98/100
# 100/100 [==============================] - 121s 1s/step - loss: 0.0636 - acc: 0.9786 - val_loss: 2.2873 - val_acc: 0.6938
# Epoch 99/100
# 100/100 [==============================] - 120s 1s/step - loss: 0.1100 - acc: 0.9713 - val_loss: 2.1451 - val_acc: 0.6874
# Epoch 100/100
# 100/100 [==============================] - 120s 1s/step - loss: 0.0659 - acc: 0.9796 - val_loss: 2.1022 - val_acc: 0.6867

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,31))
ax1.plot(epoch_list, history.history['acc'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_acc'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 31, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 31, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-257eb60bd463> in <module>()
#       4
#       5 epoch_list = list(range(1,31))
# ----> 6 ax1.plot(epoch_list, history.history['acc'], label='Train Accuracy')
#       7 ax1.plot(epoch_list, history.history['val_acc'], label='Validation Accuracy')
#       8 ax1.set_xticks(np.arange(0, 31, 5))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (30,) and (100,)

# %%
model.save('cats_dogs_cnn_img_aug.h5')

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.models import load_model
import model_evaluation_utils as meu
# %matplotlib inline

# %%
# load saved models
basic_cnn = load_model('cats_dogs_basic_cnn.h5')
img_aug_cnn = load_model('cats_dogs_cnn_img_aug.h5')
IMG_DIM = (150, 150)
input_shape = (150, 150, 3)
num2class_label_transformer = lambda l: ['cat' if x == 0 else 'dog' for x in l]
class2num_label_transformer = lambda l: [0 if x == 'cat' else 1 for x in l]

# %%
IMG_DIM = (150, 150)

test_files = glob.glob('test_data/*')
test_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in test_files]
test_imgs = np.array(test_imgs)
test_labels = [fn.split('/')[1].split('.')[0].strip() for fn in test_files]

test_imgs_scaled = test_imgs.astype('float32')
test_imgs_scaled /= 255
test_labels_enc = class2num_label_transformer(test_labels)

print('Test dataset shape:', test_imgs.shape)
print(test_labels[0:5], test_labels_enc[0:5])
# Out:
# Test dataset shape: (366, 150, 150, 3)
# ['cat', 'dog', 'cat', 'dog', 'cat'] [0, 1, 0, 1, 0]

# %%
predictions = basic_cnn.predict_classes(test_imgs_scaled, verbose=0)
predictions = num2class_label_transformer(predictions)
meu.display_model_performance_metrics(true_labels=test_labels, predicted_labels=predictions, 
                                      classes=list(set(test_labels)))
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.5902
# Precision: 0.5894
# Recall: 0.5902
# F1 Score: 0.5897
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#          dog       0.55      0.54      0.54       166
#          cat       0.62      0.64      0.63       200
#
#     accuracy                           0.59       366
#    macro avg       0.59      0.59      0.59       366
# weighted avg       0.59      0.59      0.59       366
#
#
# Prediction Confusion Matrix:
# ------------------------------
#             Predicted:
#                    dog  cat
# Actual: dog         89   77
#         cat         73  127
# /content/model_evaluation_utils.py:62: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   y_pred=predicted_labels,
# /content/model_evaluation_utils.py:64: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   print(report)
